# %%
class SomeClass:

    def method_one(self):
        # x = 23
        print('method_one', x)

    def method_two(self):
        # x = 34
        def func_one():
            # x = 56
            print('func_one', x)
        func_one()
        print('method_two', x)


x = 12
obj = SomeClass()
obj.method_one()
obj.method_two()
print('global', x)
# Out:
# method_one 12
# func_one 12
# method_two 12
# global 12

# %%
class SomeClass:

    x = 67

    def __init__(self):
        self.x = 78
        
    def method_one(self):
        x = 23
        print('method_one', x)

    def method_two(self):
        x = 34
        def func_one():
            # x = 56
            print('func_one', x)
        func_one()
        print('method_two', x)


x = 12
obj = SomeClass()
obj.method_one()
obj.method_two()
print('global', x)
# Out:
# method_one 23
# func_one 34
# method_two 34
# global 12
