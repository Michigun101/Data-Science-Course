# %%
class Cat:
    has_tail = True
    woolliness = 20  # https://goo.gl/V2NcBf

    def __init__(self, name):
        self.name = name

    def __str__(self):
        return '{} {} хвост есть? {}, пушистость - {}'.format(
            self.__class__.__name__, self.name, self.has_tail, self.woolliness)


class Bobtail(Cat):
    has_tail = False


class Sphinx(Cat):
    woolliness = 1


murzik = Bobtail(name='Мурзик')
sonya = Sphinx(name='Соня')
print(murzik)
print(sonya)
# Out:
# Bobtail Мурзик хвост есть? False, пушистость - 20
# Sphinx Соня хвост есть? True, пушистость - 1

# %%
class Robot:

    def __init__(self, model):
        self.model = model

    def __str__(self):
        return '{} model {}'.format(self.__class__.__name__, self.model)

    def operate(self):
        print('Робот ездит по кругу')


class WarRobot(Robot):

    def operate(self):
        print('Робот охраняет военный обьект')


class VacuumCleaningRobot(Robot):

    def operate(self):
        print('Робот пылесосит пол')


r2d2 = WarRobot(model='R2D2')
print(r2d2)
r2d2.operate()

print()

roomba = VacuumCleaningRobot(model='roomba M505')
print(roomba)
roomba.operate()
# Out:
# WarRobot model R2D2
# Робот охраняет военный обьект
#
# VacuumCleaningRobot model roomba M505
# Робот пылесосит пол
