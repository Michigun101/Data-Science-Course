# %%
def greet_person(person_name):
    """
    says hello
    """
    if person_name == 'Robert':
        # создаем обьект исключения и райзим его
        raise BaseException("We don't like you, Robert")
    print(f'Hi there {person_name}')


greet_person('Dolly')
# greet_person('Robert')
# Out:
# Hi there Dolly

# %%
def greet_person(person_name):
    """
    says hello
    """
    if person_name == 'Robert':
        # создаем обьект исключения и райзим его
        raise BaseException("We don't like you, Robert")
    print(f'Hi there {person_name}')



greet_person('Robert')
# Out:
# ---------------------------------------------------------------------------
# BaseException                             Traceback (most recent call last)
# Cell In[2], line 12
#       7         raise BaseException("We don't like you, Robert")
#       8     print(f'Hi there {person_name}')
# ---> 12 greet_person('Robert')
#
# Cell In[2], line 7, in greet_person(person_name)
#       2 """
#       3 says hello
#       4 """
#       5 if person_name == 'Robert':
#       6     # создаем обьект исключения и райзим его
# ----> 7     raise BaseException("We don't like you, Robert")
#       8 print(f'Hi there {person_name}')
#
# BaseException: We don't like you, Robert

# %%
def greet_person(person_name):
    """
    says hello
    """
    if person_name == 'Robert':
        # можно указать только класс исключения,
        # тогда автоматически создастся обьект исключения без параметров
        raise BaseException
    print(f'Hi there {person_name}')


greet_person('Robert')
# Out:
# ---------------------------------------------------------------------------
# BaseException                             Traceback (most recent call last)
# Cell In[3], line 12
#       8         raise BaseException
#       9     print(f'Hi there {person_name}')
# ---> 12 greet_person('Robert')
#
# Cell In[3], line 8, in greet_person(person_name)
#       2 """
#       3 says hello
#       4 """
#       5 if person_name == 'Robert':
#       6     # можно указать только класс исключения,
#       7     # тогда автоматически создастся обьект исключения без параметров
# ----> 8     raise BaseException
#       9 print(f'Hi there {person_name}')
#
# BaseException:

# %%
# Проброс исключений
try:
    raise NameError('Привет Там')
except NameError as exc:
    print(f'Исключение типа {type(exc)} пролетело мимо! его параметры {exc.args}')
    # обратите внимание на "пустой" оператор - будет переброшено исключение текущего скоупа.
    raise
# используется для зачистки возможно порушенных данных и/или логирования ошибки
# и передачи отвественности вовне - пусть там решают что делать дальше
# Out:
# Исключение типа <class 'NameError'> пролетело мимо! его параметры ('Привет Там',)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Проброс исключений
#       2 try:
# ----> 3     raise NameError('Привет Там')
#       4 except NameError as exc:
#       5     print(f'Исключение типа {type(exc)} пролетело мимо! его параметры {exc.args}')
#
# NameError: Привет Там

# %%
# можно формировать другое исключение
try:
    raise NameError('Привет Там')
except NameError as exc:
    print(f'Поймано исключение типа {type(exc)}')
    raise TypeError('Привет и тут')
# автоматом прицепляется обьект породившего исключения, в атрбибут __cause__
# Out:
# Поймано исключение типа <class 'NameError'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       2 try:
# ----> 3     raise NameError('Привет Там')
#       4 except NameError as exc:
#
# NameError: Привет Там
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 except NameError as exc:
#       5     print(f'Поймано исключение типа {type(exc)}')
# ----> 6     raise TypeError('Привет и тут')
#       7 # автоматом прицепляется обьект породившего исключения, в атрбибут __cause__
#
# TypeError: Привет и тут

# %%
# можно явно указать
try:
    raise NameError('Привет Там')
except NameError as exc:
    print(f'Поймано исключение типа {type(exc)}')
    raise TypeError('Привет и тут') from exc
# Out:
# Поймано исключение типа <class 'NameError'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       2 try:
# ----> 3     raise NameError('Привет Там')
#       4 except NameError as exc:
#
# NameError: Привет Там
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 except NameError as exc:
#       5     print(f'Поймано исключение типа {type(exc)}')
# ----> 6     raise TypeError('Привет и тут') from exc
#
# TypeError: Привет и тут

# %%
# Кастомные исключения
# Можно определять свои исключения - например исключения нашего пакета
class HeroDiedError(Exception):
    pass


class GameOverError(Exception):
    pass


try:
    raise HeroDiedError('Рядовой Райан')
except HeroDiedError as exc:
    print(f'Поймано исключение {exc}')
    raise GameOverError('Миссия провалена')
# первый параметр, как говорилось, сообщение на консоль,
# остальные параметры можно использовать для уточнения самой ошибки
# (входные данные, которые к ней привели, к примеру)
# Out:
# Поймано исключение Рядовой Райан
# ---------------------------------------------------------------------------
# HeroDiedError                             Traceback (most recent call last)
# Cell In[7], line 12
#      11 try:
# ---> 12     raise HeroDiedError('Рядовой Райан')
#      13 except HeroDiedError as exc:
#
# HeroDiedError: Рядовой Райан
#
# During handling of the above exception, another exception occurred:
#
# GameOverError                             Traceback (most recent call last)
# Cell In[7], line 15
#      13 except HeroDiedError as exc:
#      14     print(f'Поймано исключение {exc}')
# ---> 15     raise GameOverError('Миссия провалена')
#      16 # первый параметр, как говорилось, сообщение на консоль,
#      17 # остальные параметры можно использовать для уточнения самой ошибки
#      18 # (входные данные, которые к ней привели, к примеру)
#
# GameOverError: Миссия провалена

# %%
# Иногда возникает необходимость переопределить содержимое обьекта исключения - это можно сделать вот так
class DivisionError(Exception):

    def __init__(self, message, input_data=None):
        self.message = message
        self.input_data = input_data

    def __str__(self):
        return self.message
# Но этим лучше не злоупотреблять - ломаются все автоматические обработчики исключений.
# Ваш код может быть библиотекой, которую будут использовать другие программисты.
# И другие программисты полагаются на стандарт, не заставляйте их ковыряться в вашем коде - проклянут же.

# %%
def division(a, b):
    if a < b:
        raise DivisionError('Нельзя делить меньшее на большее', input_data=dict(a=a, b=b))
    return a/b


try:
    division(1, 2)
except DivisionError as exc:
    print(f'Поймано моё исключение {exc}, входные данные при ошибке {exc.input_data}')

# Повторюсь: переопределение стандартных компонентов Exception - так себе стиль. Но если уж очень нужно...


# Наверно, наиболее частые случаи принудительного выброса исключений:
#   - проверка типов параметров методов/функций
#   - проверка совместности параметров методов/функций
#   - нарушение возможности работы кода (неправильные данные)
# Out:
# Поймано моё исключение Нельзя делить меньшее на большее, входные данные при ошибке {'a': 1, 'b': 2}
