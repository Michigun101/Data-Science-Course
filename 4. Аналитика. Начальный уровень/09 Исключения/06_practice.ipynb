# %%
def calc(line):
    # print(f'Read line {line}', flush=True)
    operand_1, operation, operand_2 = line.split(' ')
    operand_1 = int(operand_1)
    operand_2 = int(operand_2)
    if operation == '+':
        value = operand_1 + operand_2
    elif operation == '-':
        value = operand_1 - operand_2
    elif operation == '/':
        value = operand_1 / operand_2
    elif operation == '*':
        value = operand_1 / operand_2
    elif operation == '//':
        value = operand_1 // operand_2
    elif operation == '%':
        value = operand_1 % operand_2
    else:
        raise ValueError('Unknown operation {operation}')
    return value

# %%
total = 0
with open('calc.txt','r') as ff:
    for line in ff:
        line = line[:-1]
        try:
            total += calc(line)
        except ValueError as exc:
            if 'unpack' in exc.args[0]:
                print(f'Не хватает операндов {exc} в строке {line}')
            else:
                print(f'Не могу преобразовать к целому {exc} в строке {line}')

print(f'Total {total}')
# Out:
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 360 288
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 301 23 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 214
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 77 16 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 464 406
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 27
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 739
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 800 309 /
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 129
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 912 591
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 420 47 //
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 629 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 575
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 191 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 226
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 23 493
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке / 574
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 215 //
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 726 *
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 653 504
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 536 67 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 910
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 191
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 227 214
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 387 212
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 153 207 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 578 472
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 757
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 177 +
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 439 603
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 728 360 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 261 775 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 159
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 761 470 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 871 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 695 618 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 536 832
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 449 598
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 374 809 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 349 260 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 22 260
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 218
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 490 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке *
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 265 336
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 188 660
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 135 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 120
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 480 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 785
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 172 136
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке /
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 529 701
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 88
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 847
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 323 561 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке /
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 102 147
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 387 833 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 491
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 695 460
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 675 628
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 137 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 773
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 918
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке + 420
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 921
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 159
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 113 844 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 711 5 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 561
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 19 448
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке 967 669 *
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке % 996
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 732 751
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке 683 865 *
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 93 769
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 308
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 660
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 455 979 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 271 154 //
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 402 339
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 601
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 440 415
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 983
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 832 919 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 923
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 386 313 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 74
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 245 516 -
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 804 189
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 126 478
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 181 73 -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 506 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 599 42 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 764 6
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 374 413 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 371 385
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 255 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 886 186 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 960 566
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 864 202 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 677 417 /
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 432 598
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 88
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 107 156
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 817 686
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке % 966
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 236
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 573 243
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 505 608
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 892 646 -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 112 //
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 130 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 483 716
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 186 314
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 302 156 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 901
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 453 595 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 366
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке % 805
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 484 81
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 306 557
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 926 384 -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 978 376
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 247 421 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 975 469
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 976
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 398
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 17 100 /
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 600 245
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 161 685 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 725 785 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 434
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 93 620
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 67 990
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 454 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 263 488 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 410
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 744
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 121
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 807 255
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 774 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 128
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 350 617 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 891
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке *
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 718 829
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 92 418
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 404
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 999 923 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 781
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 106 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 107 526 %
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 591 627
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 666
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 169 263 -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке % 945
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 285 578 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 851 303
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 702 223 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке 74 626 *
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке /
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 248 117
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 98 418
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 295 269 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 48
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 941 842
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 388
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 892
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 286 793
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 139 294
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 212 268
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 459 689
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 209 157 -
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 19 400
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 772
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 390 231
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 208
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 783
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 439
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке 199 336 *
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 742 103
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 340 680 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 248 645
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 765
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 215 412 //
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 733 837 //
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 444 996 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 706 211
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 659
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 213 100 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 512
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 602
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 207 380
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке + 410 15
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 447 871 //
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 353 33 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке 949 691 -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке +
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 695 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке *
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 580
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 355 837 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 472 *
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке -
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 688
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 895 336
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке / 683
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 763 760
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 43
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке % 238 306
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке //
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке * 802 430
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 645 +
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке / 173 635
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке *
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 633
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 68
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 101 650
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 261
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 587 747 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке - 612
# Не могу преобразовать к целому invalid literal for int() with base 10: '-' в строке - 245 256
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 958 246 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке % 837
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 432
# Не могу преобразовать к целому invalid literal for int() with base 10: '%' в строке 345 302 %
# Не могу преобразовать к целому invalid literal for int() with base 10: '*' в строке 274 624 *
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 91 %
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке 905
# Не могу преобразовать к целому invalid literal for int() with base 10: '+' в строке 157 924 +
# Не могу преобразовать к целому invalid literal for int() with base 10: '/' в строке 820 462 /
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке // 879 680
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке %
# Не могу преобразовать к целому invalid literal for int() with base 10: '//' в строке 193 997 //
# Не хватает операндов not enough values to unpack (expected 3, got 1) в строке
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке * 807
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 121 +
# Не хватает операндов not enough values to unpack (expected 3, got 2) в строке 995 23
# Total 2025104.1094394112
