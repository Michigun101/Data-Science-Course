# %% [markdown]
# # Чтение и запись данных
#
# ## Чтение из баз данных с помощью pandas и sqlalchemy
#
# ### Проверка практики

# %%
import urllib.request as req
import json
import pandas as pd

# %% [markdown]
# #### Поиск идентификатора города

# %%
url = ("https://api.open-meteo.com/v1/forecast?"
       "latitude=55.7558&longitude=37.6176&current_weather=true")

with req.urlopen(url) as session:
    response1 = session.read().decode()
    data = json.loads(response1)
data[0]
# Out:
# {'title': 'Moscow',
#  'location_type': 'City',
#  'woeid': 2122265,
#  'latt_long': '55.756950,37.614971'}

# %% [markdown]
# #### Получение истории погоды

# %%
url = 'https://www.metaweather.com/api/location/2122265/2020/04/28/'

with req.urlopen(url) as session:
    response1 = session.read().decode()
    data = json.loads(response1)
data
# Out:
# [{'id': 4520607007899648,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-28T18:27:32.227221Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.67,
#   'max_temp': 10.915,
#   'the_temp': 9.965,
#   'wind_speed': 4.5501686624777955,
#   'wind_direction': 297.50133470847635,
#   'air_pressure': 1009.0,
#   'humidity': 39,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5728158202462208,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-28T15:27:32.320780Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.67,
#   'max_temp': 10.915,
#   'the_temp': 9.92,
#   'wind_speed': 4.5501686624777955,
#   'wind_direction': 297.50133470847635,
#   'air_pressure': 1009.0,
#   'humidity': 39,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5480870762774528,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T12:27:32.389465Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3049999999999997,
#   'max_temp': 10.225,
#   'the_temp': 8.145,
#   'wind_speed': 4.519928933365148,
#   'wind_direction': 308.33499428378383,
#   'air_pressure': 1009.5,
#   'humidity': 51,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5972593918083072,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T09:27:32.493205Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.195,
#   'max_temp': 9.915,
#   'the_temp': 8.025,
#   'wind_speed': 4.555980100031815,
#   'wind_direction': 308.6673835118722,
#   'air_pressure': 1009.5,
#   'humidity': 51,
#   'visibility': 10.53690199236459,
#   'predictability': 73},
#  {'id': 5468569036914688,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T06:27:31.423059Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.425,
#   'max_temp': 10.260000000000002,
#   'the_temp': 8.765,
#   'wind_speed': 4.571307277080517,
#   'wind_direction': 308.6673835118722,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 12.849024198679711,
#   'predictability': 73},
#  {'id': 5212616366489600,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T03:27:31.446036Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.26,
#   'max_temp': 10.635000000000002,
#   'the_temp': 8.75,
#   'wind_speed': 4.755430377080516,
#   'wind_direction': 307.6709904229787,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 13.045998866618945,
#   'predictability': 73},
#  {'id': 4888443760934912,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T00:27:32.632727Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.8449999999999998,
#   'max_temp': 12.600000000000001,
#   'the_temp': 12.435,
#   'wind_speed': 5.2744841032370955,
#   'wind_direction': 311.2624574246146,
#   'air_pressure': 1000.0,
#   'humidity': 37,
#   'visibility': 15.173573828839576,
#   'predictability': 73},
#  {'id': 5844479674155008,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T21:27:31.816560Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.8449999999999998,
#   'max_temp': 12.600000000000001,
#   'the_temp': 11.585,
#   'wind_speed': 5.848629469903762,
#   'wind_direction': 292.88373023762034,
#   'air_pressure': 1003.0,
#   'humidity': 46,
#   'visibility': 10.872131750576632,
#   'predictability': 73},
#  {'id': 4722492750954496,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T18:27:34.511103Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.3250000000000002,
#   'max_temp': 10.8,
#   'the_temp': 9.23,
#   'wind_speed': 4.374458585675654,
#   'wind_direction': 307.34963261827176,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.100368845939713,
#   'predictability': 73},
#  {'id': 6043165666574336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T15:27:34.462190Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.3250000000000002,
#   'max_temp': 10.8,
#   'the_temp': 9.225000000000001,
#   'wind_speed': 4.404284319008988,
#   'wind_direction': 307.34963261827176,
#   'air_pressure': 1008.5,
#   'humidity': 48,
#   'visibility': 13.528804282987352,
#   'predictability': 73},
#  {'id': 5011162066321408,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T12:27:34.693266Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.71,
#   'max_temp': 10.66,
#   'the_temp': 9.265,
#   'wind_speed': 4.463107479514303,
#   'wind_direction': 308.02150160064934,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.008716595084703,
#   'predictability': 73},
#  {'id': 5429401602752512,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T09:27:35.595486Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.89,
#   'max_temp': 10.825,
#   'the_temp': 9.344999999999999,
#   'wind_speed': 4.524861279514304,
#   'wind_direction': 310.0061151618099,
#   'air_pressure': 1009.0,
#   'humidity': 46,
#   'visibility': 11.97040533285612,
#   'predictability': 73},
#  {'id': 5102355563413504,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T06:27:34.409498Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.8500000000000001,
#   'max_temp': 10.965,
#   'the_temp': 9.22,
#   'wind_speed': 4.55965800335905,
#   'wind_direction': 310.0061151618099,
#   'air_pressure': 1009.5,
#   'humidity': 46,
#   'visibility': 12.825101407778572,
#   'predictability': 71},
#  {'id': 5725551492857856,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T03:27:34.619624Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.0150000000000001,
#   'max_temp': 11.030000000000001,
#   'the_temp': 9.17,
#   'wind_speed': 4.724570870025716,
#   'wind_direction': 301.82355249485084,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 13.320644933587847,
#   'predictability': 71},
#  {'id': 6241938028101632,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T00:27:34.530307Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 12.2,
#   'the_temp': 10.52,
#   'wind_speed': 4.747770154068241,
#   'wind_direction': 298.04209422388783,
#   'air_pressure': 1000.5,
#   'humidity': 51,
#   'visibility': 14.89084993637159,
#   'predictability': 73},
#  {'id': 6353475308879872,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-26T21:27:34.739365Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 12.2,
#   'the_temp': 10.125,
#   'wind_speed': 5.224981887401575,
#   'wind_direction': 290.7808478210698,
#   'air_pressure': 1003.5,
#   'humidity': 56,
#   'visibility': 10.639738924679868,
#   'predictability': 73},
#  {'id': 5481074538840064,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T18:27:37.523136Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.8050000000000002,
#   'max_temp': 11.1,
#   'the_temp': 9.434999999999999,
#   'wind_speed': 5.189363735398605,
#   'wind_direction': 309.9989829823174,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 12.717914877117632,
#   'predictability': 73},
#  {'id': 5909991951171584,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T15:27:37.218842Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.8050000000000002,
#   'max_temp': 11.1,
#   'the_temp': 9.434999999999999,
#   'wind_speed': 5.2117330353986056,
#   'wind_direction': 309.9989829823174,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.315052592857711,
#   'predictability': 73},
#  {'id': 5689896956067840,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T12:27:37.800754Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.7349999999999999,
#   'max_temp': 11.205,
#   'the_temp': 9.465,
#   'wind_speed': 5.2009626433468545,
#   'wind_direction': 312.002747204715,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 12.117670305416368,
#   'predictability': 70},
#  {'id': 5056103127711744,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T09:27:38.809776Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.7149999999999999,
#   'max_temp': 11.16,
#   'the_temp': 9.28,
#   'wind_speed': 4.984644510013521,
#   'wind_direction': 313.0008130560872,
#   'air_pressure': 1010.0,
#   'humidity': 51,
#   'visibility': 9.706750079535514,
#   'predictability': 70},
#  {'id': 6345560019697664,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T06:27:37.417696Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.795,
#   'max_temp': 10.969999999999999,
#   'the_temp': 9.309999999999999,
#   'wind_speed': 4.98381588924945,
#   'wind_direction': 315.0,
#   'air_pressure': 1010.0,
#   'humidity': 47,
#   'visibility': 13.75342996898115,
#   'predictability': 73},
#  {'id': 5520572165390336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T03:27:38.230928Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 10.95,
#   'the_temp': 9.205,
#   'wind_speed': 5.086974955916117,
#   'wind_direction': 317.6663655959727,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 14.929064264694185,
#   'predictability': 73},
#  {'id': 6085597175218176,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-04-26T00:27:37.693172Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.425,
#   'max_temp': 9.765,
#   'the_temp': 7.755000000000001,
#   'wind_speed': 4.090296863925342,
#   'wind_direction': 330.86725894359245,
#   'air_pressure': 1005.0,
#   'humidity': 58,
#   'visibility': 13.767721506402609,
#   'predictability': 73},
#  {'id': 4707287694311424,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T21:27:38.712171Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.425,
#   'max_temp': 9.765,
#   'the_temp': 7.404999999999999,
#   'wind_speed': 4.560052163925342,
#   'wind_direction': 323.2935424263512,
#   'air_pressure': 1007.5,
#   'humidity': 61,
#   'visibility': 12.833489918873777,
#   'predictability': 73},
#  {'id': 5386597774131200,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T18:27:40.705815Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.305,
#   'max_temp': 10.19,
#   'the_temp': 8.89,
#   'wind_speed': 5.370316047320979,
#   'wind_direction': 318.6661282155967,
#   'air_pressure': 1009.0,
#   'humidity': 48,
#   'visibility': 12.383617175693947,
#   'predictability': 71},
#  {'id': 6023018310533120,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T15:27:41.716182Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.305,
#   'max_temp': 10.19,
#   'the_temp': 8.91,
#   'wind_speed': 5.415054647320979,
#   'wind_direction': 318.6661282155967,
#   'air_pressure': 1008.5,
#   'humidity': 50,
#   'visibility': 13.665816630875685,
#   'predictability': 71},
#  {'id': 4880358568886272,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T12:27:40.193497Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.385,
#   'max_temp': 10.29,
#   'the_temp': 9.155000000000001,
#   'wind_speed': 5.559626948460988,
#   'wind_direction': 319.99643554570355,
#   'air_pressure': 1008.0,
#   'humidity': 49,
#   'visibility': 12.785644337071503,
#   'predictability': 70},
#  {'id': 6627355910995968,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T09:27:40.708779Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.395,
#   'max_temp': 11.100000000000001,
#   'the_temp': 9.0,
#   'wind_speed': 4.411555015127655,
#   'wind_direction': 323.6745232343287,
#   'air_pressure': 1008.0,
#   'humidity': 48,
#   'visibility': 12.244430028632785,
#   'predictability': 70},
#  {'id': 5603415172317184,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T06:27:40.410376Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.75,
#   'max_temp': 11.375,
#   'the_temp': 9.2,
#   'wind_speed': 3.6969782489222935,
#   'wind_direction': 322.3349942837838,
#   'air_pressure': 1009.5,
#   'humidity': 48,
#   'visibility': 11.768770380975106,
#   'predictability': 71},
#  {'id': 6349476761436160,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T03:27:40.433114Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.02,
#   'max_temp': 11.504999999999999,
#   'the_temp': 9.205,
#   'wind_speed': 4.0752244489222935,
#   'wind_direction': 321.0024421460581,
#   'air_pressure': 1010.0,
#   'humidity': 49,
#   'visibility': 13.349849379623002,
#   'predictability': 71},
#  {'id': 4563868535750656,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-25T00:27:41.036470Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3449999999999998,
#   'max_temp': 13.825,
#   'the_temp': 12.14,
#   'wind_speed': 4.635702711492882,
#   'wind_direction': 294.40350450294295,
#   'air_pressure': 1007.0,
#   'humidity': 46,
#   'visibility': 13.470706076513164,
#   'predictability': 73},
#  {'id': 5227287303684096,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T21:27:39.897827Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3449999999999998,
#   'max_temp': 13.825,
#   'the_temp': 12.155000000000001,
#   'wind_speed': 5.015980811492882,
#   'wind_direction': 294.40350450294295,
#   'air_pressure': 1008.5,
#   'humidity': 49,
#   'visibility': 11.535445498289986,
#   'predictability': 73},
#  {'id': 5456787337641984,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T18:27:43.595633Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.005,
#   'max_temp': 11.04,
#   'the_temp': 9.54,
#   'wind_speed': 4.614086924123121,
#   'wind_direction': 317.29157811967093,
#   'air_pressure': 1009.0,
#   'humidity': 49,
#   'visibility': 11.869743199713671,
#   'predictability': 73},
#  {'id': 5800593429889024,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T15:27:42.924522Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.005,
#   'max_temp': 11.04,
#   'the_temp': 9.504999999999999,
#   'wind_speed': 4.621543357456455,
#   'wind_direction': 324.6503690081608,
#   'air_pressure': 1009.0,
#   'humidity': 51,
#   'visibility': 13.088873478883322,
#   'predictability': 73},
#  {'id': 6473013509750784,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T12:27:43.599229Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.6,
#   'max_temp': 10.82,
#   'the_temp': 9.225,
#   'wind_speed': 4.334884093130783,
#   'wind_direction': 323.9759968906734,
#   'air_pressure': 1008.5,
#   'humidity': 50,
#   'visibility': 12.689021116678596,
#   'predictability': 71},
#  {'id': 5767946779492352,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T09:27:44.727634Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.4,
#   'max_temp': 11.844999999999999,
#   'the_temp': 9.21,
#   'wind_speed': 4.02979695979745,
#   'wind_direction': 304.881289290963,
#   'air_pressure': 1009.0,
#   'humidity': 48,
#   'visibility': 11.603174958243855,
#   'predictability': 71},
#  {'id': 5835349378990080,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T06:27:43.555093Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.905,
#   'max_temp': 12.67,
#   'the_temp': 9.74,
#   'wind_speed': 4.0119844447944,
#   'wind_direction': 288.84468559373204,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 11.976619044778493,
#   'predictability': 71},
#  {'id': 6735633311596544,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T03:27:44.303546Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.85,
#   'max_temp': 12.61,
#   'the_temp': 9.565000000000001,
#   'wind_speed': 3.7627742114610676,
#   'wind_direction': 303.3167434401916,
#   'air_pressure': 1009.5,
#   'humidity': 49,
#   'visibility': 13.109068042631035,
#   'predictability': 71},
#  {'id': 4598092177342464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T00:27:43.733175Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.715,
#   'max_temp': 13.07,
#   'the_temp': 8.955,
#   'wind_speed': 4.150096426896259,
#   'wind_direction': 291.4155746148685,
#   'air_pressure': 1005.0,
#   'humidity': 55,
#   'visibility': 13.350470750815239,
#   'predictability': 73},
#  {'id': 6154505781510144,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T21:27:43.327709Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.715,
#   'max_temp': 13.07,
#   'the_temp': 7.74,
#   'wind_speed': 4.558631790344389,
#   'wind_direction': 265.5,
#   'air_pressure': 1005.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5503780722311168,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T18:27:47.671974Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.68,
#   'the_temp': 9.53,
#   'wind_speed': 2.9891352501391872,
#   'wind_direction': 282.0,
#   'air_pressure': 1011.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5311494768033792,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T15:27:48.571545Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.68,
#   'the_temp': 9.53,
#   'wind_speed': 2.9891352501391872,
#   'wind_direction': 282.0,
#   'air_pressure': 1011.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4823482380582912,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-23T12:27:46.721449Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.56,
#   'the_temp': 10.64,
#   'wind_speed': 3.250111150878867,
#   'wind_direction': 255.5,
#   'air_pressure': 1004.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 75},
#  {'id': 5516129525039104,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T09:27:46.328368Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.9749999999999996,
#   'max_temp': 11.815000000000001,
#   'the_temp': 10.64,
#   'wind_speed': 3.705111150878867,
#   'wind_direction': 275.0,
#   'air_pressure': 1004.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5766464948666368,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T06:27:46.480384Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.01,
#   'max_temp': 12.01,
#   'the_temp': 10.06,
#   'wind_speed': 3.910163644317188,
#   'wind_direction': 282.5,
#   'air_pressure': 1005.0,
#   'humidity': 52,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5554822784745472,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T03:27:46.413528Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.13,
#   'max_temp': 12.469999999999999,
#   'the_temp': 10.06,
#   'wind_speed': 3.6701636443171877,
#   'wind_direction': 264.0,
#   'air_pressure': 1005.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4619790352121856,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-23T00:27:47.933745Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.88,
#   'max_temp': 12.34,
#   'the_temp': 10.14,
#   'wind_speed': 4.701639823431162,
#   'wind_direction': 251.5,
#   'air_pressure': 1001.0,
#   'humidity': 68,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5012406533095424,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-22T21:27:47.913412Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.88,
#   'max_temp': 12.34,
#   'the_temp': 10.14,
#   'wind_speed': 4.701639823431162,
#   'wind_direction': 251.5,
#   'air_pressure': 1001.0,
#   'humidity': 68,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6098047698206720,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-22T18:27:50.338686Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.025,
#   'max_temp': 14.559999999999999,
#   'the_temp': 12.59,
#   'wind_speed': 2.3005929372464804,
#   'wind_direction': 311.5,
#   'air_pressure': 1012.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5538383193440256,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-22T15:27:50.115038Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.025,
#   'max_temp': 14.559999999999999,
#   'the_temp': 12.59,
#   'wind_speed': 2.3005929372464804,
#   'wind_direction': 311.5,
#   'air_pressure': 1012.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6316427323637760,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T12:27:49.195811Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.01,
#   'max_temp': 14.26,
#   'the_temp': 12.75,
#   'wind_speed': 2.943712121212121,
#   'wind_direction': 275.0,
#   'air_pressure': 1009.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6714499220373504,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'SW',
#   'created': '2020-04-22T09:27:51.222209Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.64,
#   'max_temp': 14.48,
#   'the_temp': 12.75,
#   'wind_speed': 4.673712121212121,
#   'wind_direction': 223.5,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4745102733869056,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2020-04-22T06:27:54.915948Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.375,
#   'max_temp': 13.745000000000001,
#   'the_temp': 11.37,
#   'wind_speed': 4.878764614650441,
#   'wind_direction': 226.0,
#   'air_pressure': 1006.0,
#   'humidity': 49,
#   'visibility': 9.999726596675416,
#   'predictability': 75},
#  {'id': 6531665583144960,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T03:27:50.021761Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.75,
#   'max_temp': 12.145,
#   'the_temp': 11.37,
#   'wind_speed': 4.498764614650441,
#   'wind_direction': 261.0,
#   'air_pressure': 1006.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6310368534069248,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T00:27:51.614409Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.07,
#   'max_temp': 10.65,
#   'the_temp': 5.77,
#   'wind_speed': 4.191185874492961,
#   'wind_direction': 276.0,
#   'air_pressure': 995.0,
#   'humidity': 75,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6458815757156352,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-21T21:27:51.068481Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.07,
#   'max_temp': 10.65,
#   'the_temp': 5.77,
#   'wind_speed': 4.191185874492961,
#   'wind_direction': 276.0,
#   'air_pressure': 995.0,
#   'humidity': 75,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5245224026636288,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T18:27:53.555798Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 5100067990011904,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T15:27:53.109905Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 5886596224122880,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T12:27:53.103622Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 4527590893158400,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-21T09:27:52.980890Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.05,
#   'max_temp': 10.815000000000001,
#   'the_temp': 5.89,
#   'wind_speed': 3.541423685675654,
#   'wind_direction': 30.50000000000001,
#   'air_pressure': 1004.0,
#   'humidity': 64,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5697636487135232,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-21T06:27:53.199225Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.69,
#   'max_temp': 11.02,
#   'the_temp': 8.53,
#   'wind_speed': 3.5755991012487076,
#   'wind_direction': 52.500000000000014,
#   'air_pressure': 1006.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5413790688477184,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-04-21T03:27:53.339675Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.53,
#   'max_temp': 9.24,
#   'the_temp': 8.53,
#   'wind_speed': 1.721198202497415,
#   'wind_direction': 121.0,
#   'air_pressure': 1006.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6336877072220160,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T00:27:52.507494Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.42,
#   'max_temp': 10.92,
#   'the_temp': 9.65,
#   'wind_speed': 2.945299451204963,
#   'wind_direction': 1.0,
#   'air_pressure': 1005.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6126731503075328,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-20T21:27:53.730576Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.42,
#   'max_temp': 10.92,
#   'the_temp': 9.65,
#   'wind_speed': 2.945299451204963,
#   'wind_direction': 1.0,
#   'air_pressure': 1005.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4724993025900544,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-20T18:27:56.396637Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.12,
#   'max_temp': 5.25,
#   'the_temp': 4.95,
#   'wind_speed': 2.839666348524616,
#   'wind_direction': 45.0,
#   'air_pressure': 996.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4997355692621824,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-20T15:27:56.795716Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.12,
#   'max_temp': 5.25,
#   'the_temp': 4.95,
#   'wind_speed': 2.839666348524616,
#   'wind_direction': 45.0,
#   'air_pressure': 996.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5992850795790336,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSE',
#   'created': '2020-04-20T12:27:57.004340Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.94,
#   'max_temp': 14.56,
#   'the_temp': 13.83,
#   'wind_speed': 2.193440308597789,
#   'wind_direction': 148.0,
#   'air_pressure': 1007.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6250892430934016,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSE',
#   'created': '2020-04-20T09:27:56.706292Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.94,
#   'max_temp': 14.56,
#   'the_temp': 13.83,
#   'wind_speed': 2.193440308597789,
#   'wind_direction': 148.0,
#   'air_pressure': 1007.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5886764499599360,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-20T06:27:56.122840Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.33,
#   'max_temp': 12.22,
#   'the_temp': 11.36,
#   'wind_speed': 1.9013958482462419,
#   'wind_direction': 281.0,
#   'air_pressure': 1014.0,
#   'humidity': 41,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6287126788308992,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-20T03:27:55.833923Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.33,
#   'max_temp': 12.22,
#   'the_temp': 11.36,
#   'wind_speed': 1.9013958482462419,
#   'wind_direction': 281.0,
#   'air_pressure': 1014.0,
#   'humidity': 41,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 4568015662219264,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-20T00:27:56.863059Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.12,
#   'max_temp': 8.76,
#   'the_temp': 7.68,
#   'wind_speed': 1.373230334844508,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1014.0,
#   'humidity': 49,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6086405786697728,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-19T21:27:55.595543Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.12,
#   'max_temp': 8.76,
#   'the_temp': 7.68,
#   'wind_speed': 1.373230334844508,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1014.0,
#   'humidity': 49,
#   'visibility': None,
#   'predictability': 71}]

# %% [markdown]
# #### Запись в файл JSON

# %%
with open('file.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# #### Чтение из JSON в pandas DataFrame

# %%
df = pd.read_json('file.json')
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4520607007899648            Showers                  s
# 1  5728158202462208            Showers                  s
# 2  5480870762774528            Showers                  s
# 3  5972593918083072            Showers                  s
# 4  5468569036914688            Showers                  s
#
#   wind_direction_compass                      created applicable_date  \
# 0                    WNW  2020-04-28T18:27:32.227221Z      2020-04-28
# 1                    WNW  2020-04-28T15:27:32.320780Z      2020-04-28
# 2                     NW  2020-04-28T12:27:32.389465Z      2020-04-28
# 3                     NW  2020-04-28T09:27:32.493205Z      2020-04-28
# 4                     NW  2020-04-28T06:27:31.423059Z      2020-04-28
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0     3.670    10.915     9.965    4.550169      297.501335        1009.0
# 1     3.670    10.915     9.920    4.550169      297.501335        1009.0
# 2     3.305    10.225     8.145    4.519929      308.334994        1009.5
# 3     3.195     9.915     8.025    4.555980      308.667384        1009.5
# 4     1.425    10.260     8.765    4.571307      308.667384        1009.5
#
#    humidity  visibility  predictability
# 0        39   12.064543              73
# 1        39   12.064543              73
# 2        51   12.064543              73
# 3        51   10.536902              73
# 4        47   12.849024              73

# %% [markdown]
# ### Подключение к БД

# %%
pip install psycopg[binary]
# Out:
# Requirement already satisfied: psycopg[binary] in /Users/mikhail/anaconda3/envs/py313/lib/python3.13/site-packages (3.2.12)
# Collecting psycopg-binary==3.2.12 (from psycopg[binary])
#   Downloading psycopg_binary-3.2.12-cp313-cp313-macosx_10_13_x86_64.whl.metadata (2.9 kB)
# Downloading psycopg_binary-3.2.12-cp313-cp313-macosx_10_13_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 4.2 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: psycopg-binary
# Successfully installed psycopg-binary-3.2.12
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
import psycopg

# %%
conn = 'postgresql://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
#    (...)    445
#     446 """
# --> 447 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:388, in Pool._create_connection(self)
#     386 """Called by subclasses to create a new ConnectionRecord."""
# --> 388 return _ConnectionRecord(self)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:899, in _ConnectionRecord.__connect(self)
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:895, in _ConnectionRecord.__connect(self)
#     894 self.starttime = time.time()
# --> 895 self.dbapi_connection = connection = pool._invoke_creator(self)
#     896 pool.logger.debug("Created new connection %r", connection)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/create.py:661, in create_engine.<locals>.connect(connection_record)
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.3", user "readonly", database "db_ds_students", no encryption
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 4
#       1 conn = 'postgresql://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'
#       3 engine = sqlalchemy.create_engine(conn)
# ----> 4 connect = engine.connect()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3277, in Engine.connect(self)
#    3254 def connect(self) -> Connection:
#    3255     """Return a new :class:`_engine.Connection` object.
#    3256
#    3257     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3274
#    3275     """
# -> 3277     return self._connection_cls(self)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3301, in Engine.raw_connection(self)
#    3279 def raw_connection(self) -> PoolProxiedConnection:
#    3280     """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282     The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300     """
# -> 3301     return self.pool.connect()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)    445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/pool/base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/sqlalchemy/engine/default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/anaconda3/envs/py313/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.3", user "readonly", database "db_ds_students", no encryption
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords', 'links', 'ratings', 'exploratory', 'course_purchases']

# %%
df = pd.read_sql("select * from course_purchases", connect)
df.head(10)
# Out:
#                                 user_id                             course_id  \
# 0                               user_id                             course_id
# 1  ed5da480-57a2-489c-8e68-512155ab9892  fc082ec6-7721-4419-916b-06e4b560b50e
# 2  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  66583e42-987a-4c38-b168-e5ee4772a627
# 3  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  b45874ec-57c7-41e7-a38c-580330a23f50
# 4  8b1752da-599d-413a-a2e9-bc75387b2be9  2d98baac-eb91-4285-99e1-bee66018cd25
# 5  3e3b7b84-65f0-4152-815a-730bec31bb9d  83982097-8179-4ba2-affa-f8aef42fc070
# 6  3e3b7b84-65f0-4152-815a-730bec31bb9d  71a3a64e-b0ec-40ac-9952-a9833900a48e
# 7  8c390b6e-a490-44ac-b974-f5dec7f6970b  b45874ec-57c7-41e7-a38c-580330a23f50
# 8  8c390b6e-a490-44ac-b974-f5dec7f6970b  34bfd77d-4ddd-411b-af91-6d2f92dfb8ce
# 9  1affa6e8-1e05-4728-96ed-dd471f9552d1  590078fa-1cd7-4a1c-b184-839d79f9c54a
#
#    purchase_date             purchase_place
# 0  purchase_date             purchase_place
# 1     2019-03-22               Екатеринбург
# 2     2018-10-28                 Курганинск
# 3     2019-04-06                Владивосток
# 4     2019-03-23                Владивосток
# 5     2019-03-25                    Катайск
# 6     2019-02-25              Североуральск
# 7     2019-03-06                       Сочи
# 8     2019-03-26                Владивосток
# 9     2019-02-16  Александровск-Сахалинский

# %%
df = df.iloc[1:,:]
df
# Out:
#                                   user_id  \
# 1    ed5da480-57a2-489c-8e68-512155ab9892
# 2    7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 3    7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 4    8b1752da-599d-413a-a2e9-bc75387b2be9
# 5    3e3b7b84-65f0-4152-815a-730bec31bb9d
# ..                                    ...
# 149  395ab5c0-e2f1-4644-974e-29fa4f821b0e
# 150  1b681fe4-5c5a-4c60-b0a3-24241374df95
# 151  1b681fe4-5c5a-4c60-b0a3-24241374df95
# 152  9fc78a49-22bc-4c21-9ee7-1444030c371a
# 153  3e585c7d-52f7-4718-a324-71a5fec75a47
#
#                                 course_id purchase_date   purchase_place
# 1    fc082ec6-7721-4419-916b-06e4b560b50e    2019-03-22     Екатеринбург
# 2    66583e42-987a-4c38-b168-e5ee4772a627    2018-10-28       Курганинск
# 3    b45874ec-57c7-41e7-a38c-580330a23f50    2019-04-06      Владивосток
# 4    2d98baac-eb91-4285-99e1-bee66018cd25    2019-03-23      Владивосток
# 5    83982097-8179-4ba2-affa-f8aef42fc070    2019-03-25          Катайск
# ..                                    ...           ...              ...
# 149  8fba0f0c-e887-4090-84dd-121712a5b86b    2019-04-04  Санкт-Петербург
# 150  f6cc4782-0ec5-4741-8c32-6fec0ad6f14b    2018-05-30           Москва
# 151  3cc8041e-ac78-4c27-899f-c204427d3f63    2019-01-04    Южно-Курильск
# 152  fe32d4f8-9272-4be2-8a74-da8ef0c2bad8    2018-11-17            Пермь
# 153  bdd8cac0-4003-4b22-ab71-9d3272a14121    2018-12-01           Москва
#
# [153 rows x 4 columns]

# %%
df.groupby('purchase_place')['course_id'].count()
# Out:
# purchase_place
# Алдан                         1
# Александровск-Сахалинский     1
# Ангарск                       1
# Анива                         1
# Арзамас                       1
# Аршан (Бурят.)                1
# Асбест                        1
# Аша                           1
# Белогорск (Амур.)             1
# Биробиджан                    1
# Верхний Баскунчак             1
# Владивосток                  25
# Волхов                        1
# Гаврилов-Ям                   1
# Диксон                        1
# Екатеринбург                 15
# Зеленогорск (Ленин.)          1
# Златоуст                      1
# Карабудахкент                 1
# Катайск                       1
# Качканар                      1
# Колпашево                     2
# Костомукша                    1
# Крымск                        1
# Курганинск                    1
# Минусинск                     1
# Москва                       30
# Нефтеюганск                   1
# Орел                          1
# Орск                          1
# Павловский Посад              1
# Пермь                         1
# Печора                        1
# Рославль                      1
# Санкт-Петербург              19
# Саратов                       1
# Сасово                        1
# Североуральск                 1
# Сосногорск                    1
# Сочи                         20
# Тольятти                      1
# Троицк (Моск.)                1
# Тымовское                     1
# Усть-Кулом                    1
# Хужир                         1
# Шатки                         1
# Шенкурск                      1
# Южно-Курильск                 1
# Name: course_id, dtype: int64

# %%
df = pd.read_sql("select purchase_place, count(course_id) from course_purchases group by purchase_place", connect)
df.head(10)
# Out:
#               purchase_place  count
# 0                     Асбест      1
# 1  Александровск-Сахалинский      1
# 2                 Костомукша      1
# 3                       Орел      1
# 4                    Саратов      1
# 5       Зеленогорск (Ленин.)      1
# 6                  Минусинск      1
# 7                     Печора      1
# 8                    Катайск      1
# 9           Павловский Посад      1
