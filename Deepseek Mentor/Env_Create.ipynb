# %%
cd 'C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Deepseek Mentor'
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: "'C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Deepseek Mentor'"
# C:\Users\mikhail.zanochuev

# %%
cd "Desktop/Repository/Data-Science-Course/Deepseek Mentor"
virtualenv venv
# Out:
#   Cell In[25], line 1
#     cd "Desktop/Repository/Data-Science-Course/Deepseek Mentor"
#        ^
# SyntaxError: invalid syntax

# %%
cd "Desktop/Repository/Data-Science-Course/Deepseek Mentor"
# Out:
# C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\Deepseek Mentor

# %%
import pandas as pd

# %%
echo %VIRTUAL_ENV%
# Out:
# c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv

# %%
where pip
# Out:
#   Cell In[29], line 1
#     where pip
#           ^
# SyntaxError: invalid syntax

# %%
python -c "import sys; print(sys.executable)"
# Out:
#   Cell In[30], line 1
#     python -c "import sys; print(sys.executable)"
#               ^
# SyntaxError: invalid syntax
