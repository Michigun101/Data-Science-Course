# %%
! pip install -q ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\mikhail.zanochuev\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 5.9MB/s 0.9s0.9s<0.0s.1ss

# %%
results = model.train(
    data =  'C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/output_photos_rus_signes/data.yaml'
    ,epochs = 30
    ,imgsz = 640
    ,batch = 32
    ,project = 'C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/runs'
    , name = 'rus_signs'

)
# Out:
# Ultralytics 8.4.56  Python-3.13.13 torch-2.12.0+cpu CPU (AMD Ryzen 7 7730U with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course// 2/output_photos_rus_signes/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=rus_signs, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course// 2/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\mikhail.zanochuev\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 282.7KB/s 2.7s 2.7s<0.0s
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431842  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,591,010 parameters, 2,590,994 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.20.1 ms, read: 14.44.0 MB/s, size: 97.3 KB)
# train: Scanning C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\Поступашки\Лекция 2\output_photos_rus_signes\labels\train... 585 images, 4 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 585/585 360.3it/s 1.6s0.1s
# train: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\images\train\autosave09_10_2012_13_31_23_1.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# train: New cache created: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\labels\train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.10.0 ms, read: 16.64.6 MB/s, size: 108.1 KB)
# val: Scanning C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\Поступашки\Лекция 2\output_photos_rus_signes\labels\val... 73 images, 1 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 73/73 387.1it/s 0.2s.4s
# val: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\images\val\autosave09_10_2012_13_31_22_0.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# val: New cache created: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30         0G      1.425      4.456      1.029          8        640: 100% ━━━━━━━━━━━━ 19/19 15.3s/it 4:51.7s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0s/it 8.0s<23.1s
#                    all         72        136     0.0105      0.482     0.0245     0.0096
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30         0G       1.44      3.148     0.9836          8        640: 100% ━━━━━━━━━━━━ 19/19 203.7s/it 1:04:313s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5s/it 9.0s<26.0s
#                    all         72        136    0.00667      0.212      0.043     0.0193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30         0G      1.395      2.486      1.008          8        640: 100% ━━━━━━━━━━━━ 19/19 17.6s/it 5:3510.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.0s/it 10.0s29.0s
#                    all         72        136     0.0116      0.277     0.0458      0.025
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30         0G      1.337      2.099     0.9948          8        640: 100% ━━━━━━━━━━━━ 19/19 17.3s/it 5:28.5s9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.7s/it 9.3s<26.7s
#                    all         72        136       0.01      0.506      0.323      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30         0G      1.302      1.858     0.9937          8        640: 100% ━━━━━━━━━━━━ 19/19 16.5s/it 5:13.1s1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.8s/it 9.5s<27.5s
#                    all         72        136      0.838      0.107       0.53      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30         0G       1.25      1.759     0.9868          8        640: 100% ━━━━━━━━━━━━ 19/19 15.8s/it 5:01.7s3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4s/it 8.7s<25.0s
#                    all         72        136      0.957      0.259      0.736      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30         0G      1.257      1.581     0.9996          8        640: 100% ━━━━━━━━━━━━ 19/19 15.7s/it 4:58.7s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4s/it 8.8s<25.2s
#                    all         72        136      0.843       0.59       0.78      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30         0G      1.273      1.525     0.9765          8        640: 100% ━━━━━━━━━━━━ 19/19 15.7s/it 4:59.8s5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3s/it 8.6s<24.9s
#                    all         72        136      0.801        0.7      0.773      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30         0G      1.254      1.496     0.9703          8        640: 100% ━━━━━━━━━━━━ 19/19 17.1s/it 5:25.4s5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3s/it 8.6s<24.8s
#                    all         72        136      0.762      0.736      0.803      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30         0G      1.219      1.343     0.9625          8        640: 100% ━━━━━━━━━━━━ 19/19 16.2s/it 5:09.2s6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5s/it 8.9s<25.7s
#                    all         72        136      0.812      0.713      0.795      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30         0G      1.198      1.304     0.9465          8        640: 100% ━━━━━━━━━━━━ 19/19 15.9s/it 5:03.9s4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3s/it 8.6s<25.0s
#                    all         72        136      0.806      0.803       0.85      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30         0G      1.209      1.265     0.9749         32        640: 32% ━━━╸──────── 6/19 19.0s/it 1:56<4:079
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 results = model.train(
#       2     data =  'C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/output_photos_rus_signes/data.yaml'
#       3     ,epochs = 30
#       4     ,imgsz = 640
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\trainer.py:459, in BaseTrainer._do_train(self)
#     454         self.tloss = (
#     455             self.loss_items if self.tloss is None else (self.tloss * i + self.loss_items) / (i + 1)
#     456         )
#     458     # Backward
# --> 459     self.scaler.scale(self.loss).backward()
#     460 except RuntimeError as e:
#     461     is_oom = isinstance(e, torch.cuda.OutOfMemoryError)
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\autograd\__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\autograd\graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data="C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/output_photos_rus_signes/data.yaml",
    epochs=100,
    imgsz=1024,
    batch=8,
    project="C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/runs",
    name="rus_signs_1024",
    pretrained=True,
    patience=20,
    seed=42,
    fliplr=0.0,
    warmup_epochs=3,
    cos_lr=True
)
# Out:
# Ultralytics 8.4.56  Python-3.13.13 torch-2.12.0+cpu CPU (AMD Ryzen 7 7730U with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course// 2/output_photos_rus_signes/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=rus_signs_1024, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course// 2/runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs_1024, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431842  ultralytics.nn.modules.head.Detect           [6, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,591,010 parameters, 2,590,994 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 154.343.2 MB/s, size: 95.2 KB)
# train: Scanning C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\Поступашки\Лекция 2\output_photos_rus_signes\labels\train.cache... 585 images, 4 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 585/585 11.9Mit/s 0.0s
# train: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\images\train\autosave09_10_2012_13_31_23_1.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.10.0 ms, read: 144.337.2 MB/s, size: 93.2 KB)
# val: Scanning C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\Поступашки\Лекция 2\output_photos_rus_signes\labels\val.cache... 73 images, 1 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 73/73 20.4Mit/s 0.0s
# val: C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\output_photos_rus_signes\images\val\autosave09_10_2012_13_31_22_0.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 6. Possible class labels are 0-5
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs_1024\labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 0 dataloader workers
# Logging results to C:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\\ 2\runs\rus_signs_1024
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G       1.29      4.487      1.088          8       1024: 100% ━━━━━━━━━━━━ 73/73 10.2s/it 12:23.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9s/it 19.6s5.4ss
#                    all         72        136    0.00535       0.51      0.118     0.0683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.257      3.239      1.111          8       1024: 100% ━━━━━━━━━━━━ 73/73 10.1s/it 12:1810.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.2s/it 20.9s5.9ss
#                    all         72        136      0.569      0.623      0.609       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.275      2.817      1.147          8       1024: 77% ━━━━━━━━━─── 56/73 10.3s/it 9:52<2:558
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 5
#       1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolo11n.pt")
#       4
# ----> 5 results = model.train(
#       6     data="C:/Users/mikhail.zanochuev/Desktop/Repository/Data-Science-Course/Поступашки/Лекция 2/output_photos_rus_signes/data.yaml",
#       7     epochs=100,
#       8     imgsz=1024,
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\ultralytics\engine\trainer.py:459, in BaseTrainer._do_train(self)
#     454         self.tloss = (
#     455             self.loss_items if self.tloss is None else (self.tloss * i + self.loss_items) / (i + 1)
#     456         )
#     458     # Backward
# --> 459     self.scaler.scale(self.loss).backward()
#     460 except RuntimeError as e:
#     461     is_oom = isinstance(e, torch.cuda.OutOfMemoryError)
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\autograd\__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File c:\Users\mikhail.zanochuev\Desktop\Repository\Data-Science-Course\.venv\Lib\site-packages\torch\autograd\graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:
